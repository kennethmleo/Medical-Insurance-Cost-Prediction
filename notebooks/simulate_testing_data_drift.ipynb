# %%
import pandas as pd

ref = pd.read_csv("../src/data/cleaned_insurance.csv")
cur = ref.sample(frac=1, replace=True)
cur["bmi"] = cur["bmi"] * 1.05
cur.to_csv("../src/data/current_insurance.csv", index=False)
